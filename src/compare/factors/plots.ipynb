# %%
from pathlib import Path

import numpy as np
import pandas as pd
import xarray as xr

import matplotlib.pyplot as plt
import seaborn as sns

from scipy.stats import pearsonr
from sklearn.metrics import mean_squared_error, mean_absolute_error

from spicy_snow.retrieval import retrieval_from_parameters

# %%
lievens_params = [2, 0.5, 0.44]
# wus_params = [2.5, 0.2, 0.55]
# wus_v2_params = [1.5, 0.1, 0.59]

in_dir = Path('~/spicy-snow/SnowEx-Data/').expanduser().resolve()
data_dir = Path('~/scratch/spicy/SnowEx-Data/').expanduser().resolve()

def bias(x, y): return np.mean(x - y)

def get_stats(x, y):
    if type(x) == xr.DataArray: x = x.values.ravel()
    if type(y) == xr.DataArray: y = y.values.ravel()
    if type(x) == list: x = np.array(x)
    if type(y) == list: y = np.array(y)
    idx = (~np.isnan(x)) & (~np.isnan(y))
    x, y = x[idx], y[idx]
    r, p = pearsonr(x, y)
    b = bias(x, y)
    mae = mean_absolute_error(x, y)
    rmse = mean_squared_error(x, y, squared = False)
    return r, b, mae, rmse

dss = {fp.stem: xr.open_dataset(fp) for fp in in_dir.glob('*.nc')}

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (y: 69, x: 58, time: 59)
# Coordinates:
#   * x               (x) float64 -105.9 -105.9 -105.9 ... -105.9 -105.9 -105.9
#   * y               (y) float64 40.57 40.57 40.57 40.57 ... 40.51 40.51 40.5
#   * time            (time) datetime64[ns] 2020-08-02T13:09:25 ... 2021-03-31T...
#     flight_dir      (time) object ...
#     platform        (time) object ...
#     relative_orbit  (time) float64 ...
#     absolute_orbit  (time) float64 ...
#     projection      int64 ...
# Data variables:
#     snow_depth      (y, x, time) float64 ...
#     wet_snow        (time, y, x) float32 ...
#     ims             (time, y, x) float64 ...
#     confidence      (y, x) float32 ...
#     fcf             (y, x) float64 ...
#     lidar-sd        (y, x) float32 ...
#     lidar-vh        (y, x) float32 ...
#     lidar-dem       (y, x) float32 ...
#     inc             (y, x) float32 ...
# Attributes: (12/16)
#     AREA_OR_POINT:      Point
#     TIFFTAG_DATETIME:   2023:08:30 19:32:22
#     TIFFTAG_SOFTWARE:   Created with GAMMA Software www.gamma-rs.ch data2geot...
#     scale_factor:       1.0
#     add_offset:         0.0
#     resolution:         90
#     ...                 ...
#     job_name:           spicy_USCOCP_2021-04-02
#     bounds:             [-105.91836344   40.50411909 -105.86079115   40.57264...
#     site:               Cameron
#     site_abbrev:        USCOCP
#     lidar-flight-time:  2021-03-19
#     processing-date:    2023-08-30 15:01:49.226648

# %%
for stem, ds in dss.items():
    pass
